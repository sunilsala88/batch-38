# %%
l1=[55,66,77,88,99,100]
l2=[-1,-2,-3,-4,-5]
rev_list=[]
for i in l2:
    rev_list.append(l1[i])
print(rev_list)
list(range(5))
# Out:
# [100, 99, 88, 77, 66]
# [0, 1, 2, 3, 4]

# %%
l3=list(range(-1,-(len(l1)+1),-1))
rev_list2=[]
for i in l3:
    rev_list2.append(l1[i])
print(rev_list2)
# Out:
# [100, 99, 88, 77, 66, 55]
