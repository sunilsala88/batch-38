# %%
l1=[55,66,77,88,99,100]
l2=[-1,-2,-3,-4,-5]
rev_list=[]
for i in l2:
    rev_list.append(l1[i])
print(rev_list)
list(range(5))
# Out:
# [100, 99, 88, 77, 66]
# [0, 1, 2, 3, 4]

# %%
l3=list(range(-1,-(len(l1)+1),-1))
rev_list2=[]
for i in l3:
    rev_list2.append(l1[i])
print(rev_list2)
# Out:
# [100, 99, 88, 77, 66, 55]

# %%
stock_prices={'tsla':900,'aapl':150,'msft':300,'google':2800,'nvda':220}

def print_stock_prices(stock_prices:dict)->int:
    total_prices=0
    for i,j in stock_prices.items():
        print(i,j)
        total_prices+=j
    return total_prices
a=print_stock_prices(stock_prices)
print(a)
# Out:
# tsla 900
# aapl 150
# msft 300
# google 2800
# nvda 220
# 4370

# %%
# Out:
# tsla 900
# aapl 150
# msft 300
# google 2800
# nvda 220
# None
