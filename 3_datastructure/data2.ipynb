# %%
l=[22,33,44,55,7.7,'herllo']
l
# Out:
# [22, 33, 44, 55, 7.7, 'herllo']

# %%
#indexing and slicing in list
l[4]
# Out:
# 7.7

# %%
l[1:4]
# Out:
# [33, 44, 55]

# %%
l.append(100)

# %%
l.insert(1,70)

# %%
l
# Out:
# [22, 70, 33, 44, 55, 7.7, 'herllo', 100]

# %%
s1='hello'
s1[0:2]
# Out:
# 'he'

# %%
print('hello')
# Out:
# hello

# %%
a=10

# %%
b=20

# %%
a=b

# %%
a
# Out:
# 20

# %%
b
# Out:
# 20

# %%
l.remove(100)

# %%
l.pop(1)
# Out:
# 70

# %%
l
# Out:
# [22, 33, 44, 55, 7.7, 'herllo']

# %%
l.index(33)
# Out:
# 1

# %%
name='tsla'
name.index('s')
# Out:
# 1

# %% [markdown]
# sum 2 number

# %%
#add 2 number
3+10
# Out:
# 13
