# %%
import pandas as pd
df=pd.read_csv(r'/Users/algo trading 2026/batch 38/10_numpy_pandas/unicorn.csv')
df
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df

# %%
df=df.set_index('Company')

# %%
df.set_index('Year Founded',inplace=True)

# %%
df2=pd.read_csv('sbin.csv')
df2
# Out:
#                       date    open    high     low   close  volume
# 0      2019-01-01 09:15:00  297.50  297.70  296.05  296.30  116562
# 1      2019-01-01 09:16:00  296.30  296.50  296.05  296.35   57789
# 2      2019-01-01 09:17:00  296.20  296.50  296.10  296.35   42404
# 3      2019-01-01 09:18:00  296.35  296.35  295.50  295.65   87831
# 4      2019-01-01 09:19:00  295.70  295.85  295.50  295.60   37799
# ...                    ...     ...     ...     ...     ...     ...
# 19995  2019-03-18 11:15:00  296.15  296.45  296.05  296.45   33954
# 19996  2019-03-18 11:16:00  296.40  296.45  296.00  296.00   37220
# 19997  2019-03-18 11:17:00  296.00  296.00  295.80  296.00   16007
# 19998  2019-03-18 11:18:00  296.00  296.00  295.85  295.95   12154
# 19999  2019-03-18 11:19:00  296.00  296.05  295.65  295.75  118891
#
# [20000 rows x 6 columns]

# %%
df2.loc[1,'volume']
# Out:
# np.int64(57789)

# %%
df.reset_index(inplace=True)
df
# Out:
#       Year Founded      Company  Valuation Date Joined  \
# 0             2012    Bytedance        180  07-04-2017
# 1             2002       SpaceX        100  01-12-2012
# 2             2008        SHEIN        100  03-07-2018
# 3             2010       Stripe         95  23-01-2014
# 4             2005       Klarna         46  12-12-2011
# ...            ...          ...        ...         ...
# 1069          2012     Zhaogang          1  29-06-2017
# 1070          2015  Zhuan Zhuan          1  18-04-2017
# 1071          2018     Zihaiguo          1  06-05-2021
# 1072          2005         Zopa          1  19-10-2021
# 1073          2014        Zwift          1  16-09-2020
#
#                              Industry           City         Country  \
# 0             Artificial intelligence        Beijing           China
# 1                               Other      Hawthorne   United States
# 2     E-commerce & direct-to-consumer       Shenzhen           China
# ...

# %%
df
# Out:
#              Valuation Date Joined                         Industry  \
# Company
# Bytedance          180  07-04-2017          Artificial intelligence
# SpaceX             100  01-12-2012                            Other
# SHEIN              100  03-07-2018  E-commerce & direct-to-consumer
# Stripe              95  23-01-2014                          Fintech
# Klarna              46  12-12-2011                          Fintech
# ...                ...         ...                              ...
# Zhaogang             1  29-06-2017  E-commerce & direct-to-consumer
# Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# Zihaiguo             1  06-05-2021                Consumer & retail
# Zopa                 1  19-10-2021                          Fintech
# Zwift                1  16-09-2020  E-commerce & direct-to-consumer
#
#                       City         Country      Continent  Year Founded  \
# Company
# ...

# %%
df.loc['Bytedance':'SHEIN','Valuation':'Industry']
# Out:
#            Valuation Date Joined                         Industry
# Company
# Bytedance        180  07-04-2017          Artificial intelligence
# SpaceX           100  01-12-2012                            Other
# SHEIN            100  03-07-2018  E-commerce & direct-to-consumer

# %%
df.iloc[0:3,0:3]
# Out:
#            Valuation Date Joined                         Industry
# Company
# Bytedance        180  07-04-2017          Artificial intelligence
# SpaceX           100  01-12-2012                            Other
# SHEIN            100  03-07-2018  E-commerce & direct-to-consumer

# %%
df.loc['Zihaiguo','Funding']
# Out:
# np.float64(80.0)

# %%
df.iloc[1,3]
# Out:
# 'Hawthorne'

# %%
df.loc['Zopa','Year Founded']
# Out:
# np.int64(2005)

# %%
df.iloc[-2,-2]
# Out:
# np.int64(2005)
