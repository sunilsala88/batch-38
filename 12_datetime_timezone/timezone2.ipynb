# %%
# !pip install yfinance
# Out:
# ...
#   Using cached beautifulsoup4-4.15.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached multitasking-0.0.13-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached pytz-2026.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# ...
# Using cached beautifulsoup4-4.15.0-py3-none-any.whl (109 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 2.2 MB/s  0:00:01 eta 0:00:01
# ...
# Using cached multitasking-0.0.13-py3-none-any.whl (16 kB)
# ...
# Using cached pytz-2026.3.post1-py2.py3-none-any.whl (508 kB)
# ...
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [yfinance]/11 [yfinance]soup4]
# ...

# %%
import yfinance as yf
df1=yf.download('TSLA', start='2025-01-01', end='2025-12-31', interval='1h',multi_level_index=False)
df1
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                 Close        High         Low        Open  \
# Datetime
# 2025-01-02 09:30:00-05:00  380.336609  391.179993  373.410004  389.689911
# 2025-01-02 10:30:00-05:00  382.524994  382.723999  376.250000  380.269989
# 2025-01-02 11:30:00-05:00  378.679993  386.149994  378.350006  382.489990
# 2025-01-02 12:30:00-05:00  377.709991  379.059998  373.049988  378.675201
# 2025-01-02 13:30:00-05:00  377.227295  380.329895  374.869995  377.619995
# ...                               ...         ...         ...         ...
# 2025-12-30 11:30:00-05:00  462.170013  463.119995  460.690002  461.109985
# 2025-12-30 12:30:00-05:00  460.496002  462.279999  458.579987  462.130005
# 2025-12-30 13:30:00-05:00  458.614990  460.739990  457.880005  460.470001
# 2025-12-30 14:30:00-05:00  456.119995  458.709991  456.100006  458.600006
# 2025-12-30 15:30:00-05:00  454.429993  456.459991  454.040009  456.140015
#
# ...

# %%
import yfinance as yf
df2=yf.download('RELIANCE.NS', start='2025-01-01', end='2025-12-31', interval='1h',multi_level_index=False)
df2
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Close         High          Low         Open  \
# Datetime
# 2025-01-01 09:15:00+05:30  1215.500000  1217.900024  1211.599976  1215.849976
# 2025-01-01 10:15:00+05:30  1220.300049  1221.000000  1214.500000  1215.099976
# 2025-01-01 11:15:00+05:30  1220.300049  1222.550049  1216.599976  1220.349976
# 2025-01-01 12:15:00+05:30  1222.150024  1226.250000  1220.000000  1220.300049
# 2025-01-01 13:15:00+05:30  1224.150024  1225.949951  1221.199951  1222.150024
# ...                                ...          ...          ...          ...
# 2025-12-30 11:15:00+05:30  1543.199951  1546.199951  1540.199951  1545.900024
# 2025-12-30 12:15:00+05:30  1543.500000  1546.900024  1542.400024  1543.000000
# 2025-12-30 13:15:00+05:30  1543.500000  1546.400024  1542.199951  1543.500000
# 2025-12-30 14:15:00+05:30  1539.300049  1545.000000  1538.000000  1543.500000
# ...

# %%
tz1='Asia/Kolkata'
tz2='America/New_York'
tz3='UTC'
df1.index = df1.index.tz_convert(tz1)
df1
# Out:
#                                 Close        High         Low        Open  \
# Datetime
# 2025-01-02 20:00:00+05:30  380.336609  391.179993  373.410004  389.689911
# 2025-01-02 21:00:00+05:30  382.524994  382.723999  376.250000  380.269989
# 2025-01-02 22:00:00+05:30  378.679993  386.149994  378.350006  382.489990
# 2025-01-02 23:00:00+05:30  377.709991  379.059998  373.049988  378.675201
# 2025-01-03 00:00:00+05:30  377.227295  380.329895  374.869995  377.619995
# ...                               ...         ...         ...         ...
# 2025-12-30 22:00:00+05:30  462.170013  463.119995  460.690002  461.109985
# 2025-12-30 23:00:00+05:30  460.496002  462.279999  458.579987  462.130005
# 2025-12-31 00:00:00+05:30  458.614990  460.739990  457.880005  460.470001
# 2025-12-31 01:00:00+05:30  456.119995  458.709991  456.100006  458.600006
# 2025-12-31 02:00:00+05:30  454.429993  456.459991  454.040009  456.140015
#
#                              Volume
# Datetime
# ...

# %%
d1=df1.reset_index()
d1['Datetime'].dt.tz_convert(tz3)
# Out:
# 0      2025-01-02 14:30:00+00:00
# 1      2025-01-02 15:30:00+00:00
# 2      2025-01-02 16:30:00+00:00
# 3      2025-01-02 17:30:00+00:00
# 4      2025-01-02 18:30:00+00:00
#                   ...
# 1726   2025-12-30 16:30:00+00:00
# 1727   2025-12-30 17:30:00+00:00
# 1728   2025-12-30 18:30:00+00:00
# 1729   2025-12-30 19:30:00+00:00
# 1730   2025-12-30 20:30:00+00:00
# Name: Datetime, Length: 1731, dtype: datetime64[s, UTC]

# %%
d1['Datetime'].dt.tz_localize(None)
# Out:
# 0      2025-01-02 20:00:00
# 1      2025-01-02 21:00:00
# 2      2025-01-02 22:00:00
# 3      2025-01-02 23:00:00
# 4      2025-01-03 00:00:00
#                ...
# 1726   2025-12-30 22:00:00
# 1727   2025-12-30 23:00:00
# 1728   2025-12-31 00:00:00
# 1729   2025-12-31 01:00:00
# 1730   2025-12-31 02:00:00
# Name: Datetime, Length: 1731, dtype: datetime64[s]
