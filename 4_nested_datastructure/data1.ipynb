# %%
foreign_exchange = {
    "base_currency": "USD",
    "exchange_rates": 
    {
        "EUR": {
            "current_rate": 0.85,
            "historical_rates": 
            [
                {"date": "2024-01-10", "rate": 0.84},
                {"date": "2024-01-09", "rate": 0.85}
            ]
        },
    
        "JPY": {
            "current_rate": 110.00,
            "historical_rates": [
                {"date": "2024-01-10", "rate": 109.50},
                {"date": "2024-01-09", "rate": 110.20}
            ]
        }
    }
}
foreign_exchange
# Out:
# {'base_currency': 'USD',
#  'exchange_rates': {'EUR': {'current_rate': 0.85,
#    'historical_rates': [{'date': '2024-01-10', 'rate': 0.84},
#     {'date': '2024-01-09', 'rate': 0.85}]},
#   'JPY': {'current_rate': 110.0,
#    'historical_rates': [{'date': '2024-01-10', 'rate': 109.5},
#     {'date': '2024-01-09', 'rate': 110.2}]}}}

# %%
foreign_exchange.get('exchange_rates').get('JPY').get('current_rate')
# Out:
# 110.0

# %% [markdown]
# list of list

# %%
l1=[11,2,[54,64,74,84],333,44,[45,67,87,90,[65,75,85,95]]]
l1
# Out:
# [11, 2, [54, 64, 74, 84], 333, 44, [45, 67, 87, 90, [65, 75, 85, 95]]]

# %%
l1[-1][-1][0]
# Out:
# 65

# %% [markdown]
# dict of dict
