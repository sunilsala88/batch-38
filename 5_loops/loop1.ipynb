# %%
#type 1
l1=[22,33,44,55]

# %%
for i in l1:
    print(i)
# Out:
# 22
# 33
# 44
# 55

# %%
#iteration/looping
total=0
for i in l1:
    total=total+i
    print(total)
print(total)
# Out:
# 22
# 55
# 99
# 154
# 154
