# %%
#type 1
l1=[22,33,44,55]

# %%
for i in l1:
    print(i)
# Out:
# 22
# 33
# 44
# 55

# %%
#iteration/looping
total=0
for i in l1:
    total=total+i
    print(total)
print(total)
avg=total/len(l1)
print(avg)
# Out:
# 22
# 55
# 99
# 154
# 154
# 38.5

# %%
l2=[45,34,76,23,42,65]
large=l2[0]

for i in l2:
    if i>large:
        large=i
print(large)
# Out:
# 76

# %%
# Out:
# 23
