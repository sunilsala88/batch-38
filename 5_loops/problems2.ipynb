# %%
stock_prices={'AAPL': 150, 'GOOG': 2800, 'MSFT': 300, 'AMZN': 3500, 'TSLA': 700}
print(stock_prices)
portfolio=[]
while True:

    name=input('Enter stock name: (press q to quit) ').upper()

    if name=='Q':
        break

    price=stock_prices.get(name)

    if price is None:
        print('Stock not found. Please try again.')
    else:
        print(f'stock {name} is added to portfolio')
        portfolio.append(name)
print('portfolio',portfolio)
# Out:
# {'AAPL': 150, 'GOOG': 2800, 'MSFT': 300, 'AMZN': 3500, 'TSLA': 700}
# stock TSLA is added to portfolio
# stock MSFT is added to portfolio
# stock AMZN is added to portfolio
# portfolio ['TSLA', 'MSFT', 'AMZN']

# %%
l1=[22,33,44,55,66,88,99]
# l1.reverse()
l1
# Out:
# [22, 33, 44, 55, 66, 88, 99]

# %%
list(range(len(l1)-1,-1,-1))
# Out:
# [4, 3, 2, 1, 0]

# %%
rev=[]
for i in range(len(l1)-1,-1,-1):
    rev.append(l1[i])
rev
# Out:
# [99, 88, 66, 55, 44, 33, 22]

# %%
s1='hello'
r1=''
for i in range(len(s1)-1,-1,-1):
    r1=r1+s1[i]
r1
# Out:
# 'olleh'

# %%
r2=''
for i in s1:
    r2=i+r2
    print(r2)
r2
# Out:
# h
# eh
# leh
# lleh
# olleh
# 'olleh'

# %%
s1='hello'
rev = s1
for i in range(len(s1)-1, -1, -1):
    rev.replace(s1[i])
rev
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       1 s1='hello'
#       2 rev = s1
#       3 for i in range(len(s1)-1, -1, -1):
# ----> 4     rev.replace(s1[i])
#       5 rev
#
# TypeError: replace() takes at least 2 positional arguments (1 given)

# %%
'hello'.replace('h','a')
# Out:
# 'aello'

# %%
s3=['h','e','l','l','o']
length=len(s3)-1

for i in range(len(s3)//2):
    print(i,length-i)
    temp1=s3[i]
    temp2=s3[length-i]
    s3[i]=temp2
    s3[length-i]=temp1
    print(temp1,temp2)
s3
# Out:
# 0 4
# h o
# 1 3
# e l
# ['o', 'l', 'l', 'e', 'h']

# %%
''.join(s3)
# Out:
# 'olleh'

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
sentence="Python is fun to learn"
char='o'
